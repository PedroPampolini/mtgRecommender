# %% [markdown]
# # Imports

# %%
import time, json, os
from selenium import webdriver
# import by and keys
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium_stealth import stealth

# %% [markdown]
# # Constants

# %%
BASE_URL = "https://mtgdecks.net/"
FORMAT_LIST = [
  'Standard',
  'Pioneer',
  'Modern',
  'Pauper',
  'Alchemy',
  'Explorer',
  'Historic',
  'Timeless',
  'Commander',
  'Duel-Commander',
  'Brawl',
  'Historic-Brawl',
  'Legacy',
  'Vintage',
  'Premodern',
  'Old-school'
]

options = webdriver.ChromeOptions()
# options.add_argument("start-maximized")
# options.add_argument("--headless=new")
# options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
options.add_argument("--start-minimized")

# tentativa de otimização
options.add_argument("--disable-gpu")
options.add_argument("--blink-settings=imagesEnabled=false")  # Desativa imagens
options.add_argument("--disable-extensions")  # Remove extensões
options.add_argument("--disable-blink-features=AutomationControlled")  # Esconde Selenium
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
prefs = {
    "profile.managed_default_content_settings.images": 2,  # Bloqueia imagens
    "profile.managed_default_content_settings.stylesheets": 2,  # Bloqueia CSS
    "profile.managed_default_content_settings.fonts": 2,  # Bloqueia fontes
}
options.add_experimental_option("prefs", prefs)
options.page_load_strategy = "eager"

def DefaultDriver():
  driver = webdriver.Chrome(options=options)
  driver.minimize_window()
  return driver

FILENAME = "mtgdecks.json"

# %% [markdown]
# # Types

# %%
class Archetype:
  def __init__(self, name, tier, deckQuantity, format, url=''):
    self.name = name
    self.tier = tier
    self.deckQuantity = deckQuantity
    self.format = format
    self.url = self.makeUlr(name, format) if url == '' else url
    self.deckList = []
    
  def makeUlr(self, name: str, format: str):
    name = name.replace(" ", "-").lower()
    name = name.replace("/", "-")
    name = name.replace(",", "")
    name = name.replace("'", "-")
    return f"https://mtgdecks.net/{format}/{name}"
  
  def __str__(self):
    return f"[{self.name} - {self.tier} - {self.deckQuantity} - {self.format} - {self.url}]"
  
  def __repr__(self):
    return f"[{self.name} - {self.tier} - {self.deckQuantity} - {self.format} - {self.url}]"
  
  def toDict(self):
    deckListDict = []
    for deck in self.deckList:
      deckListDict.append(deck.toDict())
    return {
      "name": self.name,
      "tier": self.tier,
      "deckQuantity": self.deckQuantity,
      "format": self.format,
      "url": self.url,
      "deckList": deckListDict
    }

class Deck:
  def __init__(self, name, deckType, url, _type, rank, playersQuantity):
    self.name = name
    self.deckType = deckType
    self.playersQuantity = 0
    self.type = _type
    self.rank = rank
    self.url = url
    self.cards = []
    
  def __str__(self):
    return f"[{self.name} - {self.deckType.name} - {self.playersQuantity} - {self.type} - {self.rank} - {self.url}]"
  
  def __repr__(self):
    return f"[{self.name} - {self.deckType.name} - {self.playersQuantity} - {self.type} - {self.rank} - {self.url}]"
  
  def toDict(self):
    cardsDict = []
    # for card in self.cards:
    #   cardsDict.append(card.toDict())
    return {
      "name": self.name,
      "deckType": self.deckType.name,
      "playersQuantity": self.playersQuantity,
      "type": self.type,
      "rank": self.rank,
      "url": self.url,
      "cards": cardsDict
    }

# %% [markdown]
# # General Methods

# %%
def getFormatUrlSufix(format):
  '''Function to get the url sufix for the format'''
  return {
    'Standard': "/metagame:last-2-years",
    'Pioneer': "/metagame:last-2-years",
    'Modern': "/metagame:last-2-years",
    'Pauper': "/metagame:last-2-years",
    'Alchemy': "/metagame:last-2-years",
    'Explorer': "/metagame:last-2-years",
    'Historic': "/metagame:last-2-years",
    'Timeless': "/metagame:last-2-years",
    'Commander': "/date-6",
    'Duel-Commander': "/date-6",
    'Brawl': "/date-6",
    'Historic-Brawl': "/date-6",
    'Legacy': "/metagame:last-2-years",
    'Vintage': "/metagame:last-2-years",
    'Premodern': "/metagame:last-2-years",
    'Old-school': "/metagame:last-2-years"
  }[format]
  
def gotoFormatUrl(format: str, shouldQuit: bool = False, skipShowAll: bool = False):
  '''Enter in the mtg format page'''
  driver = DefaultDriver()
  print(f"Scrap de {format}")
  try: 
    stealth(driver,
        languages=["en-US", "en"],
        vendor="Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Inc.",
        renderer="Intel Iris OpenGL Engine",
        fix_hairline=True,
        )
    
    driver.get(BASE_URL + format + getFormatUrlSufix(format))
    print("Acessando " + format + " em " + BASE_URL + format + getFormatUrlSufix(format))
    time.sleep(1)

    driver.execute_script("window.scrollTo(0, document.body.scrollHeight * 0.5);")
    print('SCROLLOU')
    time.sleep(1)
    # seleciona o botao de show all do id archetypes-loader ou o id commander-loader
    # tirei pra buceta do commander
    if(not skipShowAll):
      WebDriverWait(driver, 10).until(lambda driver: driver.find_element(By.CSS_SELECTOR, '#archetypes-loader, #commander-loader'))
      loadMoreButton = driver.find_element(By.CSS_SELECTOR, '#archetypes-loader, #commander-loader')

      if (loadMoreButton != None):
        loadMoreButton.click()
    else:
      print("CLICA AGORA")
      time.sleep(5)

    #time.sleep(5)
    if (shouldQuit):
      driver.quit()
    return True, driver
  except Exception as e:
    print(f"Error on access format {format}: {e}")
    driver.quit()
    return False, driver
  
def getArchetypeFromHtml(archetypeListItem, format):
  '''Given a html item of a archetype list, returns it archetype object'''
  # Ordem dos td: imagem, nome, meta share, tier, decks quantity, price, ??
  name = archetypeListItem.find_element(By.CSS_SELECTOR, 'td:nth-child(2) a').text
  tier = archetypeListItem.find_element(By.CSS_SELECTOR, 'td:nth-child(4)').text
  deckQuantity = archetypeListItem.find_element(By.CSS_SELECTOR, 'td:nth-child(5)').text
  return Archetype(name, tier, deckQuantity, format)
  
def getDeckInfoFromHtml(rowInfo, rowUrl, deckType):
  '''Given a html item of a deck list, returns it deck object'''
  valuesInfo = rowInfo.find_elements(By.CSS_SELECTOR, 'td')
  valuesUrl = rowUrl.find_elements(By.CSS_SELECTOR, 'td')

  rank = valuesInfo[0].text.split('\n')[0]
  name = valuesInfo[2].text.replace('\n', ' ')
  _type = valuesInfo[4].text
  playersQuantity = valuesInfo[7].text
  playersQuantity = int(playersQuantity) if playersQuantity != '' else 0
  url = valuesUrl[1].find_element(By.CSS_SELECTOR, 'a').get_attribute('href')

  return Deck(name, deckType, url, _type, rank, playersQuantity)

def getAllArchetypes(format, driver: webdriver.Chrome):
  allArchetypes = {}
  
  WebDriverWait(driver, 10).until(lambda driver: driver.find_element(By.CSS_SELECTOR, '#allArchetypes, #commanders'))
  allArchetypesTable = driver.find_element(By.CSS_SELECTOR, '#allArchetypes, #commanders')
  # pega o tbody
  allArchetypesList = allArchetypesTable.find_element(By.CSS_SELECTOR, 'tbody')
  allArchetypesList = allArchetypesList.find_elements(By.CSS_SELECTOR, 'tr')
  print(f'Getting archetypes from {format}')
  for archetypeListItem in allArchetypesList:
    archetype = getArchetypeFromHtml(archetypeListItem, format)
    allArchetypes[archetype.name] = archetype
    
  return allArchetypes

def getDeckFromArchetype(format, archetype: Archetype):
  # PEGA A LISTA DE DECKS POR ARCHETYPE
  hasEnded = False
  page = 1
  retries = 0
  allDecksList = []
  driver = None
  print(f'Getting decks from {archetype.name} format {format} from url {archetype.url}')
  while (not hasEnded):
    try:
      if driver != None:
        driver.quit()
      driver = DefaultDriver()
      driver.get(archetype.url + f"/page:{page}")

      # PEGA A LISTA DE DECKS DE UMA PAGINA
      tableText = driver.find_element(By.CSS_SELECTOR, 'table.clickable.table.table-striped.hidden-xs tbody')
      tableUrl = driver.find_element(By.CSS_SELECTOR, 'table.clickable.table.table-striped.hidden-sm.hidden-md.hidden-lg tbody')
      rowsText = tableText.find_elements(By.CSS_SELECTOR, 'tr')   # o primeiro n tem nada, ignorar
      rowsUrl = tableUrl.find_elements(By.CSS_SELECTOR, 'tr')   # o primeiro n tem nada, ignorar

      for i in range(1, len(rowsText)):
        deck = getDeckInfoFromHtml(rowsText[i], rowsUrl[i], archetype)
        allDecksList.append(deck)
      print(f'Fez a pagina {page} - {archetype.name}')
      
      if ('disabled' in driver.find_element(By.CSS_SELECTOR, 'ul.pagination').find_elements(By.CSS_SELECTOR, 'li')[-1].get_attribute('class')):
        hasEnded = True
      page += 1
      retries = 0
    except Exception as e:
      print(f"Error on page {page} on {archetype.name} format {format}: {e}")
      retries += 1
      if retries > 3:
        page += 1
        
  return allDecksList

def save(allDecksByFormat, fileName=None):
  if fileName == None:
    fileName = FILENAME
  # verifica se tem o prefixo /data/ no nome do arquivo
  if not os.path.exists('data'):
    os.makedirs('data')
  if not fileName.startswith('data/'):
    fileName = 'data/' + fileName
  
  print("SAVING FILE")
  with open(fileName, 'w') as file:
    json.dump(allDecksByFormat, file, indent=2, default=lambda x: x.toDict())
    
def getData():
  filename = 'data/' + FILENAME
  # check if file exists
  if not os.path.exists(filename):
    return {}
  
  with open(filename, 'r') as file:
    return json.load(file)
  
  
def getDeckCards(deckUrl):
  driver = DefaultDriver()
  driver.get(deckUrl)
  
  WebDriverWait(driver, 10).until(lambda driver: driver.find_element(By.CSS_SELECTOR, 'div.wholeDeck div.cards tbody tr.cardItem'))
  cards = driver.find_elements(By.CSS_SELECTOR, 'div.wholeDeck div.cards tbody tr.cardItem')
  cardList = []
  for card in cards:
    cardInfo = card.find_elements(By.CSS_SELECTOR, 'td')[0].text
    cardQuantity = cardInfo.split(' ')[0]
    cardName = ' '.join(cardInfo.split(' ')[1:]).strip()
    cardList += [cardName] * int(cardQuantity)
    
  driver.quit()
  return cardList


def closeAllDrivers():
  import os
  drivers = ['chromedriver', 'geckodriver', 'msedgedriver', 'operadriver']
  for driver in drivers:
    os.system(f"taskkill /f /im {driver} 2>nul")

# %% [markdown]
# # Running Area
#
# - Steps:
#   - Get all formats - `gotoFormatUrl(format: str, shouldQuit: bool)`
#   - Get all archetypes by format - `getAllArchetypes(format: str, driver: webdriver.Chrome)`
#   - Get all decks by archetype - `getDeckFromArchetype(format: str, archetype: Archetype, driver: webdriver.Chrome)`
#   - Get all cards by decks - `TODO`
#
# - Already runned for:
#   - Got all archetypes by format
#   - Got [0:6] decks from standart, Pioneer and Modern until DIMIR DEATH'S SHADOW (Not done)

# %%
jsonDatabase = getData()

# %%
# Ja fiz tudo
# for format in FORMAT_LIST[8:]:
#   currentFormat = format
#   success, driver = gotoFormatUrl(currentFormat, skipShowAll=(format in ['Commander', 'Duel-Commander', 'Brawl', 'Historic-Brawl']))
#   print(f"Success: {success}")
#   archetypes = getAllArchetypes(currentFormat, driver)
#   jsonDatabase[currentFormat] = archetypes

# %%
save(jsonDatabase)
# Out:
# SAVING FILE

# %%
for currentFormat in FORMAT_LIST[7:8]:
  for archetypeName, archetype in list(jsonDatabase[currentFormat].items())[0:5]:
    if(type(archetype) == dict):
      print("Converting dict to Archetype")
      archetype = Archetype(archetypeName, archetype['tier'], archetype['deckQuantity'], currentFormat, archetype['url'])
    print(f"Getting decks from {archetypeName} format {currentFormat}")
    decks = getDeckFromArchetype(currentFormat, archetype)
    archetype.deckList = decks
    jsonDatabase[currentFormat][archetypeName] = archetype
# Out:
# Converting dict to Archetype
# Getting decks from DEATH AND TAXES format Timeless
# Getting decks from DEATH AND TAXES format Timeless from url https://mtgdecks.net/Timeless/death-taxes
# Fez a pagina 1 - DEATH AND TAXES
# Fez a pagina 2 - DEATH AND TAXES
# Fez a pagina 3 - DEATH AND TAXES

# %%
currentFormat = FORMAT_LIST[8]
nDecks = 0
for archetypeName, archetype in list(jsonDatabase[currentFormat].items())[0:5]:
  if(type(archetype) == dict):
    archetype = Archetype(archetypeName, archetype['tier'], archetype['deckQuantity'], currentFormat, archetype['url'])
  archetype.deckQuantity = int(archetype.deckQuantity) if archetype.deckQuantity.isnumeric() else int(archetype.deckQuantity[1:])
  nDecks += archetype.deckQuantity
print(f"Total de decks: {nDecks}")
# Out:
# Converting dict to Archetype
# Converting dict to Archetype
# Converting dict to Archetype
# Converting dict to Archetype
# Converting dict to Archetype
# Total de decks: 25352

# %%
closeAllDrivers()

# %%
save(jsonDatabase)
# Out:
# SAVING FILE

# %%
save(jsonDatabase['Standard'], fileName='mtgDeck.standard.json')
save(jsonDatabase['Pioneer'], fileName='mtgDeck.pioneer.json')
save(jsonDatabase['Modern'], fileName='mtgDeck.modern.json')
save(jsonDatabase['Pauper'], fileName='mtgDeck.pauper.json')
save(jsonDatabase['Alchemy'], fileName='mtgDeck.alchemy.json')
save(jsonDatabase['Explorer'], fileName='mtgDeck.explorer.json')
save(jsonDatabase['Historic'], fileName='mtgDeck.historic.json')
# Out:
# SAVING FILE
# SAVING FILE
# SAVING FILE
# SAVING FILE
# SAVING FILE

# %%
save(jsonDatabase['Timeless'], fileName='mtgDeck.timeless.json')
# Out:
# SAVING FILE

# %%
# count all decks
totalDecks = 0
for format in FORMAT_LIST:
  # print(f"Counting decks from {format}")
  for archetypeName, archetype in jsonDatabase[format].items():
    if(type(archetype) == dict):
      archetypeObj = Archetype(archetypeName, archetype['tier'], archetype['deckQuantity'], format)
      archetypeObj.deckList = archetype['deckList']
      archetype = archetypeObj
    totalDecks += len(archetype.deckList)
totalDecks
# Out:
# 362965

# %%
numberOfDecksByFormat = {}
for currentFormat in FORMAT_LIST:
  numberOfDecksByFormat[currentFormat] = 0
  for archetypeName, archetype in jsonDatabase[currentFormat].items():
    if(type(archetype) == dict):
      archetypeObj = Archetype(archetypeName, archetype['tier'], archetype['deckQuantity'], currentFormat)
      archetypeObj.deckList = archetype['deckList']
      archetype = archetypeObj
    if(archetype.deckQuantity.isnumeric()):
      numberOfDecksByFormat[currentFormat] += int(archetype.deckQuantity)
    else:
      numberOfDecksByFormat[currentFormat] += int(archetype.deckQuantity[1:])
numberOfDecksByFormat
# Out:
# {'Standard': 5087,
#  'Pioneer': 61992,
#  'Modern': 70976,
#  'Pauper': 59370,
#  'Alchemy': 355,
#  'Explorer': 4917,
#  'Historic': 1565,
#  'Timeless': 729,
#  'Commander': 1419145,
#  'Duel-Commander': 770776,
#  'Brawl': 40162,
#  'Historic-Brawl': 588930,
#  'Legacy': 52942,
#  'Vintage': 19122,
#  'Premodern': 11251,
#  'Old-school': 727}

# %%
total = sum(numberOfDecksByFormat.values())
total
# Out:
# 3108046

# %%
x = 0
for mode in list(jsonDatabase.keys())[4:]:
  x += len(jsonDatabase[mode])
x
# Out:
# 5123

# %%
x = {}
for mode in list(jsonDatabase.keys())[:7]:
  x[mode] = 0
  for archetype in jsonDatabase[mode].values():
    if type(archetype) == dict:
      archetypeObj = Archetype(archetype['name'], archetype['tier'], archetype['deckQuantity'], 'Standard', archetype['url'])
      archetypeObj.deckList = archetype['deckList']
      archetype = archetypeObj
    x[mode] += len(archetype.deckList)
x
# Out:
# {'Standard': 6680,
#  'Pioneer': 103225,
#  'Modern': 140816,
#  'Pauper': 70794,
#  'Alchemy': 4989,
#  'Explorer': 16609,
#  'Historic': 11699}

# %%
x = {mode: len(jsonDatabase[mode]) for mode in list(jsonDatabase.keys())}
sorted(x.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('Historic-Brawl', 1458),
#  ('Commander', 1055),
#  ('Duel-Commander', 731),
#  ('Modern', 609),
#  ('Pioneer', 520),
#  ('Pauper', 431),
#  ('Legacy', 425),
#  ('Explorer', 289),
#  ('Brawl', 259),
#  ('Historic', 250),
#  ('Vintage', 207),
#  ('Standard', 189),
#  ('Premodern', 140),
#  ('Timeless', 136),
#  ('Alchemy', 94),
#  ('Old-school', 74)]

# %%
# pega todos os decks que tem 's na url
# for format in FORMAT_LIST:
#   for archetypeName, archetype in jsonDatabase[format].items():
#     archetype = jsonDatabase[format][archetypeName]
#     if type(archetype) == dict:
#       archetype = Archetype(archetypeName, archetype['tier'], archetype['deckQuantity'], format)
#     url = archetype.url
#     if (type(jsonDatabase[format][archetypeName]) == dict):
#       if (jsonDatabase[format][archetypeName]['url'] != url):
#         print(f"Updating url from {jsonDatabase[format][archetypeName]['url']} to {url}")
#       jsonDatabase[format][archetypeName]['url'] = url
#     elif(type(jsonDatabase[format][archetypeName]) == Archetype):
#       if (jsonDatabase[format][archetypeName].url != url):
#         print(f"Updating url from {jsonDatabase[format][archetypeName].url} to {url}")
#       jsonDatabase[format][archetypeName].url = url
# Out:
# Updating url from https://mtgdecks.net/Modern/dimir-death's-shadow to https://mtgdecks.net/Modern/dimir-death-s-shadow
# Updating url from https://mtgdecks.net/Modern/inti's-cookbook to https://mtgdecks.net/Modern/inti-s-cookbook
# Updating url from https://mtgdecks.net/Modern/grixis-death's-shadow to https://mtgdecks.net/Modern/grixis-death-s-shadow
# Updating url from https://mtgdecks.net/Modern/rakdos-death's-shadow to https://mtgdecks.net/Modern/rakdos-death-s-shadow
# Updating url from https://mtgdecks.net/Modern/jund-death's-shadow to https://mtgdecks.net/Modern/jund-death-s-shadow
# Updating url from https://mtgdecks.net/Modern/sultai-death's-shadow to https://mtgdecks.net/Modern/sultai-death-s-shadow
# Updating url from https://mtgdecks.net/Modern/orzhov-death's-shadow to https://mtgdecks.net/Modern/orzhov-death-s-shadow
# Updating url from https://mtgdecks.net/Modern/4-color-death's-shadow to https://mtgdecks.net/Modern/4-color-death-s-shadow
# Updating url from https://mtgdecks.net/Modern/mardu-death's-shadow to https://mtgdecks.net/Modern/mardu-death-s-shadow
# Updating url from https://mtgdecks.net/Modern/thassa's-vault to https://mtgdecks.net/Modern/thassa-s-vault
# Updating url from https://mtgdecks.net/Modern/esper-death's-shadow to https://mtgdecks.net/Modern/esper-death-s-shadow
# Updating url from https://mtgdecks.net/Modern/rocco's-food to https://mtgdecks.net/Modern/rocco-s-food
# Updating url from https://mtgdecks.net/Modern/golgari-death's-shadow to https://mtgdecks.net/Modern/golgari-death-s-shadow
# Updating url from https://mtgdecks.net/Pauper/pilgrim's-auras to https://mtgdecks.net/Pauper/pilgrim-s-auras
# Updating url from https://mtgdecks.net/Explorer/thassa's-bargain to https://mtgdecks.net/Explorer/thassa-s-bargain
# Updating url from https://mtgdecks.net/Historic/grixis-death's-shadow to https://mtgdecks.net/Historic/grixis-death-s-shadow
# Updating url from https://mtgdecks.net/Historic/saheeli's-titan to https://mtgdecks.net/Historic/saheeli-s-titan
# Updating url from https://mtgdecks.net/Historic/golgari-death's-shadow to https://mtgdecks.net/Historic/golgari-death-s-shadow
# Updating url from https://mtgdecks.net/Historic/mind's-desire to https://mtgdecks.net/Historic/mind-s-desire
# Updating url from https://mtgdecks.net/Historic/rakdos-death's-shadow to https://mtgdecks.net/Historic/rakdos-death-s-shadow
# Updating url from https://mtgdecks.net/Historic/orzhov-death's-shadow to https://mtgdecks.net/Historic/orzhov-death-s-shadow
# Updating url from https://mtgdecks.net/Historic/dimir-death's-shadow to https://mtgdecks.net/Historic/dimir-death-s-shadow
# Updating url from https://mtgdecks.net/Timeless/ubx-death's-shadow to https://mtgdecks.net/Timeless/ubx-death-s-shadow
# Updating url from https://mtgdecks.net/Timeless/grixis-death's-shadow to https://mtgdecks.net/Timeless/grixis-death-s-shadow
# Updating url from https://mtgdecks.net/Timeless/jund-death's-shadow to https://mtgdecks.net/Timeless/jund-death-s-shadow
# Updating url from https://mtgdecks.net/Timeless/rakdos-death's-shadow to https://mtgdecks.net/Timeless/rakdos-death-s-shadow
# Updating url from https://mtgdecks.net/Commander/kraum,-ludevic's-opus to https://mtgdecks.net/Commander/kraum-ludevic-s-opus
# Updating url from https://mtgdecks.net/Commander/thrasios,-triton-hero to https://mtgdecks.net/Commander/thrasios-triton-hero
# Updating url from https://mtgdecks.net/Commander/etali,-primal-conqueror to https://mtgdecks.net/Commander/etali-primal-conqueror
# Updating url from https://mtgdecks.net/Commander/niv-mizzet,-parun to https://mtgdecks.net/Commander/niv-mizzet-parun
# Updating url from https://mtgdecks.net/Commander/rocco,-cabaretti-caterer to https://mtgdecks.net/Commander/rocco-cabaretti-caterer
# Updating url from https://mtgdecks.net/Commander/inalla,-archmage-ritualist to https://mtgdecks.net/Commander/inalla-archmage-ritualist
# Updating url from https://mtgdecks.net/Commander/urza,-lord-high-artificer to https://mtgdecks.net/Commander/urza-lord-high-artificer
# Updating url from https://mtgdecks.net/Commander/dihada,-binder-of-wills to https://mtgdecks.net/Commander/dihada-binder-of-wills
# Updating url from https://mtgdecks.net/Commander/bruse-tarl,-boorish-herder to https://mtgdecks.net/Commander/bruse-tarl-boorish-herder
# Updating url from https://mtgdecks.net/Commander/kediss,-emberclaw-familiar to https://mtgdecks.net/Commander/kediss-emberclaw-familiar
# Updating url from https://mtgdecks.net/Commander/glarb,-calamity's-augur to https://mtgdecks.net/Commander/glarb-calamity-s-augur
# Updating url from https://mtgdecks.net/Commander/francisco,-fowl-marauder to https://mtgdecks.net/Commander/francisco-fowl-marauder
# Updating url from https://mtgdecks.net/Commander/shorikai,-genesis-engine to https://mtgdecks.net/Commander/shorikai-genesis-engine
# Updating url from https://mtgdecks.net/Commander/wernog,-rider's-chaplain to https://mtgdecks.net/Commander/wernog-rider-s-chaplain
# Updating url from https://mtgdecks.net/Commander/tameshi,-reality-architect to https://mtgdecks.net/Commander/tameshi-reality-architect
# Updating url from https://mtgdecks.net/Commander/animar,-soul-of-elements to https://mtgdecks.net/Commander/animar-soul-of-elements
# Updating url from https://mtgdecks.net/Commander/rakdos,-the-muscle to https://mtgdecks.net/Commander/rakdos-the-muscle
# Updating url from https://mtgdecks.net/Commander/hashaton,-scarab's-fist to https://mtgdecks.net/Commander/hashaton-scarab-s-fist
# Updating url from https://mtgdecks.net/Commander/ishai,-ojutai-dragonspeaker to https://mtgdecks.net/Commander/ishai-ojutai-dragonspeaker
# Updating url from https://mtgdecks.net/Commander/bjorna,-nightfall-alchemist to https://mtgdecks.net/Commander/bjorna-nightfall-alchemist
# Updating url from https://mtgdecks.net/Commander/breya,-etherium-shaper to https://mtgdecks.net/Commander/breya-etherium-shaper
# Updating url from https://mtgdecks.net/Commander/heliod,-the-radiant-dawn to https://mtgdecks.net/Commander/heliod-the-radiant-dawn
# Updating url from https://mtgdecks.net/Commander/esika,-god-of-the-tree to https://mtgdecks.net/Commander/esika-god-of-the-tree
# Updating url from https://mtgdecks.net/Commander/chatterfang,-squirrel-general to https://mtgdecks.net/Commander/chatterfang-squirrel-general
# Updating url from https://mtgdecks.net/Commander/krenko,-mob-boss to https://mtgdecks.net/Commander/krenko-mob-boss
# Updating url from https://mtgdecks.net/Commander/nekusar,-the-mindrazer to https://mtgdecks.net/Commander/nekusar-the-mindrazer
# Updating url from https://mtgdecks.net/Commander/tasigur,-the-golden-fang to https://mtgdecks.net/Commander/tasigur-the-golden-fang
# Updating url from https://mtgdecks.net/Commander/zada,-hedron-grinder to https://mtgdecks.net/Commander/zada-hedron-grinder
# Updating url from https://mtgdecks.net/Commander/brallin,-skyshark-rider to https://mtgdecks.net/Commander/brallin-skyshark-rider
# Updating url from https://mtgdecks.net/Commander/liberator,-urza's-battlethopter to https://mtgdecks.net/Commander/liberator-urza-s-battlethopter
# Updating url from https://mtgdecks.net/Commander/sidisi,-brood-tyrant to https://mtgdecks.net/Commander/sidisi-brood-tyrant
# Updating url from https://mtgdecks.net/Commander/yeva,-nature's-herald to https://mtgdecks.net/Commander/yeva-nature-s-herald
# Updating url from https://mtgdecks.net/Commander/galadriel,-light-of-valinor to https://mtgdecks.net/Commander/galadriel-light-of-valinor
# Updating url from https://mtgdecks.net/Commander/éowyn,-shieldmaiden to https://mtgdecks.net/Commander/éowyn-shieldmaiden
# Updating url from https://mtgdecks.net/Commander/oskar,-rubbish-reclaimer to https://mtgdecks.net/Commander/oskar-rubbish-reclaimer
# Updating url from https://mtgdecks.net/Commander/mishra,-eminent-one to https://mtgdecks.net/Commander/mishra-eminent-one
# Updating url from https://mtgdecks.net/Commander/hapatra,-vizier-of-poisons to https://mtgdecks.net/Commander/hapatra-vizier-of-poisons
# Updating url from https://mtgdecks.net/Commander/yarok,-the-desecrated to https://mtgdecks.net/Commander/yarok-the-desecrated
# Updating url from https://mtgdecks.net/Commander/ixhel,-scion-of-atraxa to https://mtgdecks.net/Commander/ixhel-scion-of-atraxa
# Updating url from https://mtgdecks.net/Commander/jodah,-archmage-eternal to https://mtgdecks.net/Commander/jodah-archmage-eternal
# Updating url from https://mtgdecks.net/Commander/loot,-the-pathfinder to https://mtgdecks.net/Commander/loot-the-pathfinder
# Updating url from https://mtgdecks.net/Commander/karumonix,-the-rat-king to https://mtgdecks.net/Commander/karumonix-the-rat-king
# Updating url from https://mtgdecks.net/Commander/gonti,-canny-acquisitor to https://mtgdecks.net/Commander/gonti-canny-acquisitor
# Updating url from https://mtgdecks.net/Commander/ghalta,-primal-hunger to https://mtgdecks.net/Commander/ghalta-primal-hunger
# Updating url from https://mtgdecks.net/Commander/kasla,-the-broken-halo to https://mtgdecks.net/Commander/kasla-the-broken-halo
# Updating url from https://mtgdecks.net/Commander/kalamax,-the-stormsire to https://mtgdecks.net/Commander/kalamax-the-stormsire
# Updating url from https://mtgdecks.net/Commander/be'lakor,-the-dark-master to https://mtgdecks.net/Commander/be-lakor-the-dark-master
# Updating url from https://mtgdecks.net/Commander/raggadragga,-goreguts-boss to https://mtgdecks.net/Commander/raggadragga-goreguts-boss
# Updating url from https://mtgdecks.net/Commander/jhoira,-ageless-innovator to https://mtgdecks.net/Commander/jhoira-ageless-innovator
# Updating url from https://mtgdecks.net/Commander/kydele,-chosen-of-kruphix to https://mtgdecks.net/Commander/kydele-chosen-of-kruphix
# Updating url from https://mtgdecks.net/Commander/aminatou,-the-fateshifter to https://mtgdecks.net/Commander/aminatou-the-fateshifter
# Updating url from https://mtgdecks.net/Commander/tovolar,-dire-overlord to https://mtgdecks.net/Commander/tovolar-dire-overlord
# Updating url from https://mtgdecks.net/Commander/abdel-adrian,-gorion's-ward to https://mtgdecks.net/Commander/abdel-adrian-gorion-s-ward
# Updating url from https://mtgdecks.net/Commander/umbris,-fear-manifest to https://mtgdecks.net/Commander/umbris-fear-manifest
# Updating url from https://mtgdecks.net/Commander/marchesa,-the-black-rose to https://mtgdecks.net/Commander/marchesa-the-black-rose
# Updating url from https://mtgdecks.net/Commander/morophon,-the-boundless to https://mtgdecks.net/Commander/morophon-the-boundless
# Updating url from https://mtgdecks.net/Commander/kroxa,-titan-of-death's-hunger to https://mtgdecks.net/Commander/kroxa-titan-of-death-s-hunger
# Updating url from https://mtgdecks.net/Commander/ygra,-eater-of-all to https://mtgdecks.net/Commander/ygra-eater-of-all
# Updating url from https://mtgdecks.net/Commander/obeka,-splitter-of-seconds to https://mtgdecks.net/Commander/obeka-splitter-of-seconds
# Updating url from https://mtgdecks.net/Commander/lavinia,-azorius-renegade to https://mtgdecks.net/Commander/lavinia-azorius-renegade
# Updating url from https://mtgdecks.net/Commander/rielle,-the-everwise to https://mtgdecks.net/Commander/rielle-the-everwise
# Updating url from https://mtgdecks.net/Commander/shelob,-child-of-ungoliant to https://mtgdecks.net/Commander/shelob-child-of-ungoliant
# Updating url from https://mtgdecks.net/Commander/myrel,-shield-of-argive to https://mtgdecks.net/Commander/myrel-shield-of-argive
# Updating url from https://mtgdecks.net/Commander/ruric-thar,-the-unbowed to https://mtgdecks.net/Commander/ruric-thar-the-unbowed
# Updating url from https://mtgdecks.net/Commander/falco-spara,-pactweaver to https://mtgdecks.net/Commander/falco-spara-pactweaver
# Updating url from https://mtgdecks.net/Commander/zinnia,-valley's-voice to https://mtgdecks.net/Commander/zinnia-valley-s-voice
# Updating url from https://mtgdecks.net/Commander/rionya,-fire-dancer to https://mtgdecks.net/Commander/rionya-fire-dancer
# Updating url from https://mtgdecks.net/Commander/narci,-fable-singer to https://mtgdecks.net/Commander/narci-fable-singer
# Updating url from https://mtgdecks.net/Commander/saruman,-the-white-hand to https://mtgdecks.net/Commander/saruman-the-white-hand
# Updating url from https://mtgdecks.net/Commander/florian,-voldaren-scion to https://mtgdecks.net/Commander/florian-voldaren-scion
# Updating url from https://mtgdecks.net/Commander/azusa,-lost-but-seeking to https://mtgdecks.net/Commander/azusa-lost-but-seeking
# Updating url from https://mtgdecks.net/Commander/tinybones,-trinket-thief to https://mtgdecks.net/Commander/tinybones-trinket-thief
# Updating url from https://mtgdecks.net/Commander/volo,-guide-to-monsters to https://mtgdecks.net/Commander/volo-guide-to-monsters
# Updating url from https://mtgdecks.net/Commander/syr-gwyn,-hero-of-ashvale to https://mtgdecks.net/Commander/syr-gwyn-hero-of-ashvale
# Updating url from https://mtgdecks.net/Commander/aminatou,-veil-piercer to https://mtgdecks.net/Commander/aminatou-veil-piercer
# Updating url from https://mtgdecks.net/Commander/gev,-scaled-scorch to https://mtgdecks.net/Commander/gev-scaled-scorch
# Updating url from https://mtgdecks.net/Commander/ulalek,-fused-atrocity to https://mtgdecks.net/Commander/ulalek-fused-atrocity
# Updating url from https://mtgdecks.net/Commander/captain-america,-first-avenger to https://mtgdecks.net/Commander/captain-america-first-avenger
# Updating url from https://mtgdecks.net/Commander/loot,-the-key-to-everything to https://mtgdecks.net/Commander/loot-the-key-to-everything
# Updating url from https://mtgdecks.net/Commander/jacob-hauken,-inspector to https://mtgdecks.net/Commander/jacob-hauken-inspector
# Updating url from https://mtgdecks.net/Commander/admiral-brass,-unsinkable to https://mtgdecks.net/Commander/admiral-brass-unsinkable
# Updating url from https://mtgdecks.net/Commander/jorn,-god-of-winter to https://mtgdecks.net/Commander/jorn-god-of-winter
# Updating url from https://mtgdecks.net/Commander/koll,-the-forgemaster to https://mtgdecks.net/Commander/koll-the-forgemaster
# Updating url from https://mtgdecks.net/Commander/yusri,-fortune's-flame to https://mtgdecks.net/Commander/yusri-fortune-s-flame
# Updating url from https://mtgdecks.net/Commander/ovika,-enigma-goliath to https://mtgdecks.net/Commander/ovika-enigma-goliath
# Updating url from https://mtgdecks.net/Commander/slimefoot,-the-stowaway to https://mtgdecks.net/Commander/slimefoot-the-stowaway
# Updating url from https://mtgdecks.net/Commander/ziatora,-the-incinerator to https://mtgdecks.net/Commander/ziatora-the-incinerator
# Updating url from https://mtgdecks.net/Commander/phenax,-god-of-deception to https://mtgdecks.net/Commander/phenax-god-of-deception
# Updating url from https://mtgdecks.net/Commander/ayara,-first-of-locthwain to https://mtgdecks.net/Commander/ayara-first-of-locthwain
# Updating url from https://mtgdecks.net/Commander/vishgraz,-the-doomhive to https://mtgdecks.net/Commander/vishgraz-the-doomhive
# Updating url from https://mtgdecks.net/Commander/toggo,-goblin-weaponsmith to https://mtgdecks.net/Commander/toggo-goblin-weaponsmith
# Updating url from https://mtgdecks.net/Commander/kona,-rescue-beastie to https://mtgdecks.net/Commander/kona-rescue-beastie
# Updating url from https://mtgdecks.net/Commander/arabella,-abandoned-doll to https://mtgdecks.net/Commander/arabella-abandoned-doll
# Updating url from https://mtgdecks.net/Commander/extus,-oriq-overlord to https://mtgdecks.net/Commander/extus-oriq-overlord
# Updating url from https://mtgdecks.net/Commander/marvo,-deep-operative to https://mtgdecks.net/Commander/marvo-deep-operative
# Updating url from https://mtgdecks.net/Commander/laelia,-the-blade-reforged to https://mtgdecks.net/Commander/laelia-the-blade-reforged
# Updating url from https://mtgdecks.net/Commander/yorion,-sky-nomad to https://mtgdecks.net/Commander/yorion-sky-nomad
# Updating url from https://mtgdecks.net/Commander/bilbo,-birthday-celebrant to https://mtgdecks.net/Commander/bilbo-birthday-celebrant
# Updating url from https://mtgdecks.net/Commander/aragorn,-king-of-gondor to https://mtgdecks.net/Commander/aragorn-king-of-gondor
# Updating url from https://mtgdecks.net/Commander/nahiri,-forged-in-fury to https://mtgdecks.net/Commander/nahiri-forged-in-fury
# Updating url from https://mtgdecks.net/Commander/skullbriar,-the-walking-grave to https://mtgdecks.net/Commander/skullbriar-the-walking-grave
# Updating url from https://mtgdecks.net/Commander/karador,-ghost-chieftain to https://mtgdecks.net/Commander/karador-ghost-chieftain
# Updating url from https://mtgdecks.net/Commander/strefan,-maurer-progenitor to https://mtgdecks.net/Commander/strefan-maurer-progenitor
# Updating url from https://mtgdecks.net/Historic-Brawl/zethi,-arcane-blademaster to https://mtgdecks.net/Historic-Brawl/zethi-arcane-blademaster
# Updating url from https://mtgdecks.net/Historic-Brawl/viconia,-nightsinger's-disciple to https://mtgdecks.net/Historic-Brawl/viconia-nightsinger-s-disciple
# Updating url from https://mtgdecks.net/Historic-Brawl/mavinda,-students'-advocate to https://mtgdecks.net/Historic-Brawl/mavinda-students--advocate
# Updating url from https://mtgdecks.net/Historic-Brawl/doran,-the-siege-tower to https://mtgdecks.net/Historic-Brawl/doran-the-siege-tower
# Updating url from https://mtgdecks.net/Historic-Brawl/kardur,-doomscourge to https://mtgdecks.net/Historic-Brawl/kardur-doomscourge
# Updating url from https://mtgdecks.net/Historic-Brawl/kraum,-ludevic's-opus to https://mtgdecks.net/Historic-Brawl/kraum-ludevic-s-opus
# Updating url from https://mtgdecks.net/Historic-Brawl/rona,-sheoldred's-faithful to https://mtgdecks.net/Historic-Brawl/rona-sheoldred-s-faithful
# Updating url from https://mtgdecks.net/Historic-Brawl/a-saheeli,-filigree-master to https://mtgdecks.net/Historic-Brawl/a-saheeli-filigree-master
# Updating url from https://mtgdecks.net/Historic-Brawl/frodo,-adventurous-hobbit to https://mtgdecks.net/Historic-Brawl/frodo-adventurous-hobbit
# Updating url from https://mtgdecks.net/Historic-Brawl/egon,-god-of-death to https://mtgdecks.net/Historic-Brawl/egon-god-of-death
# Updating url from https://mtgdecks.net/Historic-Brawl/sigrid,-god-favored to https://mtgdecks.net/Historic-Brawl/sigrid-god-favored
# Updating url from https://mtgdecks.net/Historic-Brawl/jaheira,-harper-emissary to https://mtgdecks.net/Historic-Brawl/jaheira-harper-emissary
# Updating url from https://mtgdecks.net/Historic-Brawl/arwen,-weaver-of-hope to https://mtgdecks.net/Historic-Brawl/arwen-weaver-of-hope
# Updating url from https://mtgdecks.net/Historic-Brawl/uchbenbak,-the-great-mistake to https://mtgdecks.net/Historic-Brawl/uchbenbak-the-great-mistake
# Updating url from https://mtgdecks.net/Historic-Brawl/uurg,-spawn-of-turg to https://mtgdecks.net/Historic-Brawl/uurg-spawn-of-turg
# Updating url from https://mtgdecks.net/Historic-Brawl/animar,-soul-of-elements to https://mtgdecks.net/Historic-Brawl/animar-soul-of-elements
# Updating url from https://mtgdecks.net/Historic-Brawl/alora,-cheerful-swashbuckler to https://mtgdecks.net/Historic-Brawl/alora-cheerful-swashbuckler
# Updating url from https://mtgdecks.net/Historic-Brawl/gylwain,-casting-director to https://mtgdecks.net/Historic-Brawl/gylwain-casting-director
# Updating url from https://mtgdecks.net/Historic-Brawl/garruk,-savage-herald to https://mtgdecks.net/Historic-Brawl/garruk-savage-herald
# Updating url from https://mtgdecks.net/Historic-Brawl/chandra,-flame's-catalyst to https://mtgdecks.net/Historic-Brawl/chandra-flame-s-catalyst
# Updating url from https://mtgdecks.net/Historic-Brawl/lukamina,-crocodile-form to https://mtgdecks.net/Historic-Brawl/lukamina-crocodile-form
# Updating url from https://mtgdecks.net/Historic-Brawl/mishra,-excavation-prodigy to https://mtgdecks.net/Historic-Brawl/mishra-excavation-prodigy
# Updating url from https://mtgdecks.net/Historic-Brawl/urza,-powerstone-prodigy to https://mtgdecks.net/Historic-Brawl/urza-powerstone-prodigy
# Updating url from https://mtgdecks.net/Historic-Brawl/karlach,-tiefling-zealot to https://mtgdecks.net/Historic-Brawl/karlach-tiefling-zealot
# Updating url from https://mtgdecks.net/Historic-Brawl/liliana,-death-mage to https://mtgdecks.net/Historic-Brawl/liliana-death-mage
# Updating url from https://mtgdecks.net/Historic-Brawl/basri,-devoted-paladin to https://mtgdecks.net/Historic-Brawl/basri-devoted-paladin
# Updating url from https://mtgdecks.net/Historic-Brawl/syr-armont,-the-redeemer to https://mtgdecks.net/Historic-Brawl/syr-armont-the-redeemer
# Updating url from https://mtgdecks.net/Historic-Brawl/legolas,-counter-of-kills to https://mtgdecks.net/Historic-Brawl/legolas-counter-of-kills
# Updating url from https://mtgdecks.net/Historic-Brawl/butterbur,-bree-innkeeper to https://mtgdecks.net/Historic-Brawl/butterbur-bree-innkeeper
# Updating url from https://mtgdecks.net/Historic-Brawl/gimli,-mournful-avenger to https://mtgdecks.net/Historic-Brawl/gimli-mournful-avenger
# Updating url from https://mtgdecks.net/Historic-Brawl/gothmog,-morgul-lieutenant to https://mtgdecks.net/Historic-Brawl/gothmog-morgul-lieutenant
# Updating url from https://mtgdecks.net/Historic-Brawl/erkenbrand,-lord-of-westfold to https://mtgdecks.net/Historic-Brawl/erkenbrand-lord-of-westfold
# Updating url from https://mtgdecks.net/Historic-Brawl/gimli,-counter-of-kills to https://mtgdecks.net/Historic-Brawl/gimli-counter-of-kills
# Updating url from https://mtgdecks.net/Historic-Brawl/glorfindel,-dauntless-rescuer to https://mtgdecks.net/Historic-Brawl/glorfindel-dauntless-rescuer
# Updating url from https://mtgdecks.net/Historic-Brawl/witch-king,-bringer-of-ruin to https://mtgdecks.net/Historic-Brawl/witch-king-bringer-of-ruin
# Updating url from https://mtgdecks.net/Historic-Brawl/bill-ferny,-bree-swindler to https://mtgdecks.net/Historic-Brawl/bill-ferny-bree-swindler
# Updating url from https://mtgdecks.net/Historic-Brawl/éowyn,-lady-of-rohan to https://mtgdecks.net/Historic-Brawl/éowyn-lady-of-rohan
# Updating url from https://mtgdecks.net/Historic-Brawl/jeleva,-nephalia's-scourge to https://mtgdecks.net/Historic-Brawl/jeleva-nephalia-s-scourge
# Updating url from https://mtgdecks.net/Historic-Brawl/sarevok,-mighty-usurper to https://mtgdecks.net/Historic-Brawl/sarevok-mighty-usurper
# Updating url from https://mtgdecks.net/Historic-Brawl/hanna,-ship's-navigator to https://mtgdecks.net/Historic-Brawl/hanna-ship-s-navigator
# Updating url from https://mtgdecks.net/Historic-Brawl/éowyn,-shieldmaiden to https://mtgdecks.net/Historic-Brawl/éowyn-shieldmaiden
# Updating url from https://mtgdecks.net/Historic-Brawl/narfi,-betrayer-king to https://mtgdecks.net/Historic-Brawl/narfi-betrayer-king
# Updating url from https://mtgdecks.net/Historic-Brawl/neyali,-suns'-vanguard to https://mtgdecks.net/Historic-Brawl/neyali-suns--vanguard
# Updating url from https://mtgdecks.net/Historic-Brawl/ral,-caller-of-storms to https://mtgdecks.net/Historic-Brawl/ral-caller-of-storms
# Updating url from https://mtgdecks.net/Historic-Brawl/rowan,-scholar-of-sparks to https://mtgdecks.net/Historic-Brawl/rowan-scholar-of-sparks
# Updating url from https://mtgdecks.net/Historic-Brawl/palladia-mors,-the-ruiner to https://mtgdecks.net/Historic-Brawl/palladia-mors-the-ruiner
# Updating url from https://mtgdecks.net/Historic-Brawl/karn,-the-great-creator to https://mtgdecks.net/Historic-Brawl/karn-the-great-creator
# Updating url from https://mtgdecks.net/Historic-Brawl/vraska,-regal-gorgon to https://mtgdecks.net/Historic-Brawl/vraska-regal-gorgon
# Updating url from https://mtgdecks.net/Historic-Brawl/angrath,-minotaur-pirate to https://mtgdecks.net/Historic-Brawl/angrath-minotaur-pirate
# Updating url from https://mtgdecks.net/Historic-Brawl/domri,-city-smasher to https://mtgdecks.net/Historic-Brawl/domri-city-smasher
# Updating url from https://mtgdecks.net/Historic-Brawl/samut,-tyrant-smasher to https://mtgdecks.net/Historic-Brawl/samut-tyrant-smasher
# Updating url from https://mtgdecks.net/Historic-Brawl/samut,-the-tested to https://mtgdecks.net/Historic-Brawl/samut-the-tested
# Updating url from https://mtgdecks.net/Historic-Brawl/kazarov,-sengir-pureblood to https://mtgdecks.net/Historic-Brawl/kazarov-sengir-pureblood
# Updating url from https://mtgdecks.net/Historic-Brawl/rona,-disciple-of-gix to https://mtgdecks.net/Historic-Brawl/rona-disciple-of-gix
# Updating url from https://mtgdecks.net/Historic-Brawl/vivien,-arkbow-ranger to https://mtgdecks.net/Historic-Brawl/vivien-arkbow-ranger
# Updating url from https://mtgdecks.net/Historic-Brawl/arlinn,-voice-of-the-pack to https://mtgdecks.net/Historic-Brawl/arlinn-voice-of-the-pack
# Updating url from https://mtgdecks.net/Historic-Brawl/melira,-the-living-cure to https://mtgdecks.net/Historic-Brawl/melira-the-living-cure
# Updating url from https://mtgdecks.net/Historic-Brawl/teferi,-timebender to https://mtgdecks.net/Historic-Brawl/teferi-timebender
# Updating url from https://mtgdecks.net/Historic-Brawl/niambi,-faithful-healer to https://mtgdecks.net/Historic-Brawl/niambi-faithful-healer
# Updating url from https://mtgdecks.net/Historic-Brawl/nahiri,-storm-of-stone to https://mtgdecks.net/Historic-Brawl/nahiri-storm-of-stone
# Updating url from https://mtgdecks.net/Historic-Brawl/temmet,-vizier-of-naktamun to https://mtgdecks.net/Historic-Brawl/temmet-vizier-of-naktamun
# Updating url from https://mtgdecks.net/Historic-Brawl/chandra,-pyromaster to https://mtgdecks.net/Historic-Brawl/chandra-pyromaster
# Updating url from https://mtgdecks.net/Historic-Brawl/chandra,-fire-artisan to https://mtgdecks.net/Historic-Brawl/chandra-fire-artisan
# Updating url from https://mtgdecks.net/Historic-Brawl/sarkhan,-dragonsoul to https://mtgdecks.net/Historic-Brawl/sarkhan-dragonsoul
# Updating url from https://mtgdecks.net/Historic-Brawl/chandra,-bold-pyromancer to https://mtgdecks.net/Historic-Brawl/chandra-bold-pyromancer
# Updating url from https://mtgdecks.net/Historic-Brawl/chandra,-novice-pyromancer to https://mtgdecks.net/Historic-Brawl/chandra-novice-pyromancer
# Updating url from https://mtgdecks.net/Historic-Brawl/rhuk,-hexgold-nabber to https://mtgdecks.net/Historic-Brawl/rhuk-hexgold-nabber
# Updating url from https://mtgdecks.net/Historic-Brawl/slobad,-iron-goblin to https://mtgdecks.net/Historic-Brawl/slobad-iron-goblin
# Updating url from https://mtgdecks.net/Historic-Brawl/jaya,-venerated-firemage to https://mtgdecks.net/Historic-Brawl/jaya-venerated-firemage
# Updating url from https://mtgdecks.net/Historic-Brawl/neheb,-dreadhorde-champion to https://mtgdecks.net/Historic-Brawl/neheb-dreadhorde-champion
# Updating url from https://mtgdecks.net/Historic-Brawl/mu-yanling,-celestial-wind to https://mtgdecks.net/Historic-Brawl/mu-yanling-celestial-wind
# Updating url from https://mtgdecks.net/Historic-Brawl/kasmina,-enigmatic-mentor to https://mtgdecks.net/Historic-Brawl/kasmina-enigmatic-mentor
# Updating url from https://mtgdecks.net/Historic-Brawl/vraska,-scheming-gorgon to https://mtgdecks.net/Historic-Brawl/vraska-scheming-gorgon
# Updating url from https://mtgdecks.net/Historic-Brawl/tetzimoc,-primal-death to https://mtgdecks.net/Historic-Brawl/tetzimoc-primal-death
# Updating url from https://mtgdecks.net/Historic-Brawl/rowan,-fearless-sparkmage to https://mtgdecks.net/Historic-Brawl/rowan-fearless-sparkmage
# Updating url from https://mtgdecks.net/Historic-Brawl/sorin,-vampire-lord to https://mtgdecks.net/Historic-Brawl/sorin-vampire-lord
# Updating url from https://mtgdecks.net/Historic-Brawl/liliana,-the-necromancer to https://mtgdecks.net/Historic-Brawl/liliana-the-necromancer
# Updating url from https://mtgdecks.net/Historic-Brawl/linvala,-keeper-of-silence to https://mtgdecks.net/Historic-Brawl/linvala-keeper-of-silence
# Updating url from https://mtgdecks.net/Historic-Brawl/ajani,-inspiring-leader to https://mtgdecks.net/Historic-Brawl/ajani-inspiring-leader
# Updating url from https://mtgdecks.net/Historic-Brawl/gideon,-the-oathsworn to https://mtgdecks.net/Historic-Brawl/gideon-the-oathsworn
# Updating url from https://mtgdecks.net/Historic-Brawl/tomik,-distinguished-advokist to https://mtgdecks.net/Historic-Brawl/tomik-distinguished-advokist
# Updating url from https://mtgdecks.net/Historic-Brawl/lena,-selfless-champion to https://mtgdecks.net/Historic-Brawl/lena-selfless-champion
# Updating url from https://mtgdecks.net/Historic-Brawl/alirios,-enraptured to https://mtgdecks.net/Historic-Brawl/alirios-enraptured
# Updating url from https://mtgdecks.net/Historic-Brawl/ajani,-wise-counselor to https://mtgdecks.net/Historic-Brawl/ajani-wise-counselor
# Updating url from https://mtgdecks.net/Historic-Brawl/ormos,-archive-keeper to https://mtgdecks.net/Historic-Brawl/ormos-archive-keeper
# Updating url from https://mtgdecks.net/Historic-Brawl/callaphe,-beloved-of-the-sea to https://mtgdecks.net/Historic-Brawl/callaphe-beloved-of-the-sea
# Updating url from https://mtgdecks.net/Historic-Brawl/jace,-ingenious-mind-mage to https://mtgdecks.net/Historic-Brawl/jace-ingenious-mind-mage
# Updating url from https://mtgdecks.net/Historic-Brawl/tezzeret,-cruel-machinist to https://mtgdecks.net/Historic-Brawl/tezzeret-cruel-machinist
# Updating url from https://mtgdecks.net/Historic-Brawl/slinn-voda,-the-rising-deep to https://mtgdecks.net/Historic-Brawl/slinn-voda-the-rising-deep
# Updating url from https://mtgdecks.net/Historic-Brawl/ambergris,-agent-of-tyranny to https://mtgdecks.net/Historic-Brawl/ambergris-agent-of-tyranny
# Updating url from https://mtgdecks.net/Historic-Brawl/squee,-dubious-monarch to https://mtgdecks.net/Historic-Brawl/squee-dubious-monarch
# Updating url from https://mtgdecks.net/Historic-Brawl/brimaz,-blight-of-oreskos to https://mtgdecks.net/Historic-Brawl/brimaz-blight-of-oreskos
# Updating url from https://mtgdecks.net/Historic-Brawl/tura-kennerüd,-skyknight to https://mtgdecks.net/Historic-Brawl/tura-kennerüd-skyknight
# Updating url from https://mtgdecks.net/Historic-Brawl/dorothea,-vengeful-victim to https://mtgdecks.net/Historic-Brawl/dorothea-vengeful-victim
# Updating url from https://mtgdecks.net/Historic-Brawl/viconia,-disciple-of-arcana to https://mtgdecks.net/Historic-Brawl/viconia-disciple-of-arcana
# Updating url from https://mtgdecks.net/Legacy/ubx-death's-shadow to https://mtgdecks.net/Legacy/ubx-death-s-shadow
# Updating url from https://mtgdecks.net/Legacy/thassa's-paradigm to https://mtgdecks.net/Legacy/thassa-s-paradigm
# Updating url from https://mtgdecks.net/Legacy/mind's-desire to https://mtgdecks.net/Legacy/mind-s-desire
# Updating url from https://mtgdecks.net/Legacy/dragon's-approach to https://mtgdecks.net/Legacy/dragon-s-approach
# Updating url from https://mtgdecks.net/Legacy/thassa's-lash to https://mtgdecks.net/Legacy/thassa-s-lash
# Updating url from https://mtgdecks.net/Legacy/urza's-echo to https://mtgdecks.net/Legacy/urza-s-echo
# Updating url from https://mtgdecks.net/Legacy/tibal's-trickery to https://mtgdecks.net/Legacy/tibal-s-trickery
# Updating url from https://mtgdecks.net/Legacy/rakdos-death's-shadow to https://mtgdecks.net/Legacy/rakdos-death-s-shadow
# Updating url from https://mtgdecks.net/Legacy/thassa's-witch to https://mtgdecks.net/Legacy/thassa-s-witch
# Updating url from https://mtgdecks.net/Legacy/inti's-currency to https://mtgdecks.net/Legacy/inti-s-currency
# Updating url from https://mtgdecks.net/Legacy/mono-black-death's-shadow to https://mtgdecks.net/Legacy/mono-black-death-s-shadow
# Updating url from https://mtgdecks.net/Vintage/painter's-grindstone to https://mtgdecks.net/Vintage/painter-s-grindstone
# Updating url from https://mtgdecks.net/Vintage/ub-death's-shadow to https://mtgdecks.net/Vintage/ub-death-s-shadow
# Updating url from https://mtgdecks.net/Vintage/thassa's-hermit to https://mtgdecks.net/Vintage/thassa-s-hermit
# Updating url from https://mtgdecks.net/Vintage/tibal's-trickery to https://mtgdecks.net/Vintage/tibal-s-trickery
# Updating url from https://mtgdecks.net/Vintage/thassa's-mill to https://mtgdecks.net/Vintage/thassa-s-mill
